# %%
import pandas as pd

# %%
df = pd.read_csv("Gesture-1-1707585759.csv")

# %%
df
# Out:
#      -98.500541687  288.950683594  50.9479217529  79.083366394  277.370391846  \
# 0        29.858068     264.390411      38.862530      0.000000       0.000000
# 1       -15.284715     254.700134      43.178204      0.000000       0.000000
# 2        -2.938552     231.400665      21.344242      0.000000       0.000000
# 3        10.447781     240.650497      55.477421      0.000000       0.000000
# 4         9.950449     243.555313      86.980598      0.000000       0.000000
# ..             ...            ...            ...           ...            ...
# 184       0.000000       0.000000       0.000000     72.613113     507.543976
# 185       0.000000       0.000000       0.000000     58.135910     503.709747
# 186       0.000000       0.000000       0.000000     51.500042     499.499084
# 187       0.000000       0.000000       0.000000     54.054665     508.130219
# 188       0.000000       0.000000       0.000000     56.428944     506.465881
#
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Sample data
lpx = df.iloc[:,0]
lpy = df.iloc[:,1]
lpz = df.iloc[:,2]

rpx = df.iloc[:,3]
rpy = df.iloc[:,4]
rpz = df.iloc[:,5]

lnx = df.iloc[:,6]
lny = df.iloc[:,7]
lnz = df.iloc[:,8]

rnx = df.iloc[:,9]
rny = df.iloc[:,10]
rnz = df.iloc[:,11]

# Create 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# # Plot points for first set of coordinates
# ax.scatter(lpx, lpy, lpz, c='r', marker='o', label='left position')

# # Plot points for second set of coordinates
# ax.scatter(rpx, rpy, rpz, c='b', marker='o', label='Right position')

ax.scatter(lnx, lny, lnz, c='g', marker='^', label='left normal')

ax.scatter(rnx, rny, rnz, c='y', marker='^', label='Right normal')

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Add a legend
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

df = pd.read_csv("CAR-JORDAN-1707561745.csv")

# Sample data
x = df.iloc[:,0]
y = df.iloc[:,1]
z = df.iloc[:,2]

x1 = df.iloc[:,3]
y1 = df.iloc[:,4]
z1 = df.iloc[:,5]

# Create 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot points for first set of coordinates
ax.scatter(x, y, z, c='r', marker='o', label='Left')

# Plot points for second set of coordinates
ax.scatter(x1, y1, z1, c='b', marker='^', label='Right')

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Add a legend
ax.legend()
plt.show()

# %%
import pandas as pd

# Load all CSV files into one DataFrame
dfs = []
for i in range(1, 11):
    filename = f"Gesture-2-{i}.csv"
    df = pd.read_csv(filename,header=None)
    dfs.append(df)

combined_df = pd.concat(dfs, ignore_index=True)

# %%
combined_df
# Out:
#              0           1           2          3           4          5   \
# 0    -96.066948  217.654480   58.559807   0.000000    0.000000   0.000000
# 1    -64.792137  217.277023   27.787605   0.000000    0.000000   0.000000
# 2    -69.515083  199.685669   32.010544   0.000000    0.000000   0.000000
# 3    -27.028206  159.937302  107.731102   0.000000    0.000000   0.000000
# 4      6.973917  183.862473   70.442558   0.000000    0.000000   0.000000
# ...         ...         ...         ...        ...         ...        ...
# 1029   0.000000    0.000000    0.000000 -17.241289  179.812576  76.847206
# 1030   0.000000    0.000000    0.000000  -2.910901  171.143311  45.341377
# 1031   0.000000    0.000000    0.000000  -1.790668  168.382874  54.056698
# 1032   0.000000    0.000000    0.000000 -11.871183  154.107651  82.033493
# 1033   0.000000    0.000000    0.000000 -17.037258  165.873627  92.238319
#
#             6         7         8         9         10        11  \
# ...

# %%
# Split the DataFrame into smaller DataFrames of 40 rows each
split_dfs = [combined_df[i:i+40] for i in range(0, len(combined_df), 31)]

# Save each smaller DataFrame to a separate CSV file
for i, split_df in enumerate(split_dfs):
    split_df.to_csv(f"Gesture-2.{i+1}.csv", index=False, header=False)

# %%
import pandas as pd

# Load all CSV files into one DataFrame
dfs = []
arr = [1,100]
for i in arr:
    filename = f"Gesture-3-{i}.csv"
    df = pd.read_csv(filename,header=None)
    dfs.append(df)
combined_df = pd.concat(dfs, ignore_index=True)

# %%
len(combined_df)
# Out:
# 1079

# %%
# Split the DataFrame into smaller DataFrames of 40 rows each
split_dfs = [combined_df[i:i+40] for i in range(0, len(combined_df), 31)]

# Save each smaller DataFrame to a separate CSV file
for i, split_df in enumerate(split_dfs):
    split_df.to_csv(f"Gesture-3.{i+1}.csv", index=False, header=False)
